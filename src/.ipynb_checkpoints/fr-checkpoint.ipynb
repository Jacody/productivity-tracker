# %%
import sys
import cv2
import mediapipe as mp
from PyQt5.QtWidgets import QApplication, QLabel, QWidget, QVBoxLayout
from PyQt5.QtGui import QImage, QPixmap
from PyQt5.QtCore import QTimer

# Mediapipe Gesichtserkennung initialisieren
mp_face_detection = mp.solutions.face_detection

class FaceDetectorApp(QWidget):
    def __init__(self):
        super().__init__()
        self.setWindowTitle("Face Detection")
        self.setGeometry(100, 100, 800, 600)  # Fenstergröße setzen

        # Kamera starten
        self.cap = cv2.VideoCapture(0)
        if not self.cap.isOpened():
            print("⚠️ Fehler: Kamera kann nicht geöffnet werden!")

        # QLabel für die Live-Kamera
        self.label = QLabel(self)
        layout = QVBoxLayout()
        layout.addWidget(self.label)
        self.setLayout(layout)

        # Gesichtserkennung aktivieren
        self.face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.5)

        # Timer für das Update der Kamera
        self.timer = QTimer()
        self.timer.timeout.connect(self.update_frame)
        self.timer.start(10)

    def update_frame(self):
        ret, frame = self.cap.read()
        if not ret:
            print("❌ Kein Kamerabild erhalten.")
            return
        
        # Bild in RGB umwandeln (Mediapipe benötigt RGB)
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = self.face_detection.process(frame_rgb)

        # Gesichter markieren
        if results.detections:
            print("✅ Gesicht erkannt!")
            for detection in results.detections:
                bboxC = detection.location_data.relative_bounding_box
                h, w, _ = frame.shape
                bbox = (
                    int(bboxC.xmin * w),
                    int(bboxC.ymin * h),
                    int(bboxC.width * w),
                    int(bboxC.height * h)
                )
                print(f"🟢 Bounding Box: {bbox}")
                cv2.rectangle(frame_rgb, bbox, (0, 255, 0), 2)  # Bounding Box zeichnen

        # OpenCV Frame in QImage konvertieren
        h, w, ch = frame_rgb.shape
        bytes_per_line = ch * w
        q_img = QImage(frame_rgb.data, w, h, bytes_per_line, QImage.Format_RGB888)
        pixmap = QPixmap.fromImage(q_img)

        # QLabel mit neuem Bild aktualisieren
        self.label.setPixmap(pixmap)

    def closeEvent(self, event):
        self.cap.release()
        event.accept()

# Hauptprogramm
if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = FaceDetectorApp()
    window.show()
    sys.exit(app.exec_())
# Out:
# Anderung
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739536116.929064 3705562 gl_context.cc:369] GL version: 2.1 (2.1 ATI-4.8.101), renderer: AMD Radeon Pro 450 OpenGL Engine
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1739536116.934074 3705780 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (539, -107, 569, 569)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (585, -18, 198, 198)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (597, -5, 196, 196)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (587, 0, 215, 215)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, -6, 233, 233)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (588, 3, 219, 219)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (578, 8, 226, 226)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, 14, 224, 224)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (577, 13, 221, 221)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (578, 16, 223, 223)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (580, 16, 220, 220)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, 18, 218, 218)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (580, 14, 225, 225)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (573, 14, 220, 220)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (575, 18, 216, 216)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (577, 18, 217, 217)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (576, 17, 212, 212)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (578, 18, 214, 214)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, 12, 215, 215)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, 11, 214, 214)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (580, 10, 215, 215)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (583, 3, 216, 216)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (578, 1, 222, 222)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (580, 5, 219, 219)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (579, -1, 230, 230)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (586, -5, 227, 227)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (586, -2, 225, 225)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (591, 3, 216, 216)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (595, 1, 206, 206)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (606, -8, 199, 199)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (610, -17, 201, 201)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (609, -25, 212, 212)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (609, -39, 218, 218)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (619, -39, 220, 220)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (627, -45, 220, 220)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (638, -39, 200, 200)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (634, -44, 204, 204)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (632, -42, 208, 208)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (639, -39, 201, 201)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (631, -44, 207, 207)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (633, -50, 207, 207)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (632, -44, 200, 200)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (630, -50, 209, 209)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (630, -55, 215, 215)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (632, -45, 203, 203)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (640, -39, 195, 195)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (638, -38, 195, 195)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (637, -46, 211, 211)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (635, -39, 203, 203)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (629, -46, 213, 213)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (636, -39, 203, 203)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (639, -40, 203, 203)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (640, -48, 202, 202)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (648, -40, 197, 197)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (644, -39, 199, 199)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (643, -46, 202, 202)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (644, -48, 200, 200)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (645, -48, 195, 195)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (637, -55, 204, 204)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (639, -56, 210, 210)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (646, -48, 197, 197)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (643, -52, 205, 205)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (640, -54, 205, 205)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (638, -60, 210, 210)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (645, -47, 201, 201)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (235, 16, 404, 404)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (240, 19, 395, 395)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (239, 18, 401, 401)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (234, 15, 407, 407)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (236, 15, 405, 405)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: (652, -49, 197, 197)
# ✅ Gesicht erkannt!
# 🟢 Bounding Box: