# %%
import sys
import cv2
import time
import mediapipe as mp
from face_detection import FaceDetectorApp
from PyQt5.QtWidgets import QApplication, QLabel, QWidget, QVBoxLayout
from PyQt5.QtGui import QImage, QPixmap
from PyQt5.QtCore import QTimer

mp_face_detection = mp.solutions.face_detection

class FaceDetectorApp(QWidget):
    def __init__(self):
        super().__init__()
        self.setWindowTitle("Face Detection")
        self.setGeometry(100, 100, 800, 600)

        self.cap = cv2.VideoCapture(0)
        if not self.cap.isOpened():
            print("⚠️ Fehler: Kamera kann nicht geöffnet werden!")

        self.label = QLabel(self)
        layout = QVBoxLayout()
        layout.addWidget(self.label)
        self.setLayout(layout)

        self.face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.8)

        self.timer = QTimer()
        self.timer.timeout.connect(self.update_frame)
        self.timer.start(10)

        self.last_face_detected_time = time.time()
        self.no_face_logged = False
        self.face_was_missing = True

    def update_frame(self):
        ret, frame = self.cap.read()
        if not ret:
            print("❌ Kein Kamerabild erhalten.")
            return
        
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = self.face_detection.process(frame_rgb)

        face_detected = False

        if results.detections:
            for detection in results.detections:
                confidence = detection.score[0]
                if confidence >= 0.8:
                    face_detected = True
                    self.last_face_detected_time = time.time()
                    self.no_face_logged = False

                    if self.face_was_missing:
                        print("✅ Face detected")
                        self.face_was_missing = False

                    bboxC = detection.location_data.relative_bounding_box
                    h, w, _ = frame.shape
                    bbox = (
                        int(bboxC.xmin * w),
                        int(bboxC.ymin * h),
                        int(bboxC.width * w),
                        int(bboxC.height * h)
                    )

                    cv2.rectangle(frame_rgb, bbox, (0, 255, 0), 2)
                    cv2.putText(frame_rgb, f"{confidence:.2f}", (bbox[0], bbox[1] - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        if not face_detected and time.time() - self.last_face_detected_time > 2:
            if not self.no_face_logged:
                print("❌ No face detected")
                self.no_face_logged = True
                self.face_was_missing = True

        h, w, ch = frame_rgb.shape
        bytes_per_line = ch * w
        q_img = QImage(frame_rgb.data, w, h, bytes_per_line, QImage.Format_RGB888)
        pixmap = QPixmap.fromImage(q_img)
        self.label.setPixmap(pixmap)

    def closeEvent(self, event):
        self.cap.release()
        event.accept()

if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = FaceDetectorApp()
    window.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import mediapipe as mp
#       5 import nbimporter
# ----> 6 from face_detection import FaceDetectorApp
#       7 from PyQt5.QtWidgets import QApplication, QLabel, QWidget, QVBoxLayout
#       8 from PyQt5.QtGui import QImage, QPixmap
#
# File ~/face_recognition/lib/python3.9/site-packages/nbimporter.py:110, in NotebookLoader.load_module(self, fullname)
#     108         # run the code in the module
#     109         codeobj = compile(tree, filename=path, mode='exec')
# --> 110         exec(codeobj, mod.__dict__)
#     111 finally:
#     112     self.shell.user_ns = save_user_ns
#
# File ~/Desktop/GitHub/productivity-tracker/src/face_detection.ipynb:6
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
# ----> 6    "id": "ba5f90b7-6994-49fc-aa02-5e6aa79b371d",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import sys\n",
#      11     "import cv2\n",
#      12     "import time\n",
#      13     "import mediapipe as mp\n",
#      14     "import nbimporter\n",
#      15     "from face_detection import FaceDetectorApp\n",
#      16     "from PyQt5.QtWidgets import QApplication, QLabel, QWidget, QVBoxLayout\n",
#      17     "from PyQt5.QtGui import QImage, QPixmap\n",
#      18     "from PyQt5.QtCore import QTimer\n",
#      19     "\n",
#      20     "mp_face_detection = mp.solutions.face_detection\n",
#      21     "\n",
#      22     "class FaceDetectorApp(QWidget):\n",
#      23     "    def __init__(self):\n",
#      24     "        super().__init__()\n",
#      25     "        self.setWindowTitle(\"Face Detection\")\n",
#      26     "        self.setGeometry(100, 100, 800, 600)\n",
#      27     "\n",
#      28     "        self.cap = cv2.VideoCapture(0)\n",
#      29     "        if not self.cap.isOpened():\n",
#      30     "            print(\"⚠️ Fehler: Kamera kann nicht geöffnet werden!\")\n",
#      31     "\n",
#      32     "        self.label = QLabel(self)\n",
#      33     "        layout = QVBoxLayout()\n",
#      34     "        layout.addWidget(self.label)\n",
#      35     "        self.setLayout(layout)\n",
#      36     "\n",
#      37     "        self.face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.8)\n",
#      38     "\n",
#      39     "        self.timer = QTimer()\n",
#      40     "        self.timer.timeout.connect(self.update_frame)\n",
#      41     "        self.timer.start(10)\n",
#      42     "\n",
#      43     "        self.last_face_detected_time = time.time()\n",
#      44     "        self.no_face_logged = False\n",
#      45     "        self.face_was_missing = True\n",
#      46     "\n",
#      47     "    def update_frame(self):\n",
#      48     "        ret, frame = self.cap.read()\n",
#      49     "        if not ret:\n",
#      50     "            print(\"❌ Kein Kamerabild erhalten.\")\n",
#      51     "            return\n",
#      52     "        \n",
#      53     "        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)\n",
#      54     "        results = self.face_detection.process(frame_rgb)\n",
#      55     "\n",
#      56     "        face_detected = False\n",
#      57     "\n",
#      58     "        if results.detections:\n",
#      59     "            for detection in results.detections:\n",
#      60     "                confidence = detection.score[0]\n",
#      61     "                if confidence >= 0.8:\n",
#      62     "                    face_detected = True\n",
#      63     "                    self.last_face_detected_time = time.time()\n",
#      64     "                    self.no_face_logged = False\n",
#      65     "\n",
#      66     "                    if self.face_was_missing:\n",
#      67     "                        print(\"✅ Face detected\")\n",
#      68     "                        self.face_was_missing = False\n",
#      69     "\n",
#      70     "                    bboxC = detection.location_data.relative_bounding_box\n",
#      71     "                    h, w, _ = frame.shape\n",
#      72     "                    bbox = (\n",
#      73     "                        int(bboxC.xmin * w),\n",
#      74     "                        int(bboxC.ymin * h),\n",
#      75     "                        int(bboxC.width * w),\n",
#      76     "                        int(bboxC.height * h)\n",
#      77     "                    )\n",
#      78     "\n",
#      79     "                    cv2.rectangle(frame_rgb, bbox, (0, 255, 0), 2)\n",
#      80     "                    cv2.putText(frame_rgb, f\"{confidence:.2f}\", (bbox[0], bbox[1] - 10),\n",
#      81     "                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)\n",
#      82     "\n",
#      83     "        if not face_detected and time.time() - self.last_face_detected_time > 2:\n",
#      84     "            if not self.no_face_logged:\n",
#      85     "                print(\"❌ No face detected\")\n",
#      86     "                self.no_face_logged = True\n",
#      87     "                self.face_was_missing = True\n",
#      88     "\n",
#      89     "        h, w, ch = frame_rgb.shape\n",
#      90     "        bytes_per_line = ch * w\n",
#      91     "        q_img = QImage(frame_rgb.data, w, h, bytes_per_line, QImage.Format_RGB888)\n",
#      92     "        pixmap = QPixmap.fromImage(q_img)\n",
#      93     "        self.label.setPixmap(pixmap)\n",
#      94     "\n",
#      95     "    def closeEvent(self, event):\n",
#      96     "        self.cap.release()\n",
#      97     "        event.accept()\n",
#      98     "\n",
#      99     "if __name__ == \"__main__\":\n",
#     100     "    app = QApplication(sys.argv)\n",
#     101     "    window = FaceDetectorApp()\n",
#     102     "    window.show()\n",
#     103     "    sys.exit(app.exec_())\n"
#     104    ]
#     105   }
#     106  ],
#     107  "metadata": {
#     108   "kernelspec": {
#     109    "display_name": "Python 3 (ipykernel)",
#     110    "language": "python",
#     111    "name": "python3"
#     112   },
#     113   "language_info": {
#     114    "codemirror_mode": {
#     115     "name": "ipython",
#     116     "version": 3
#     117    },
#     118    "file_extension": ".py",
#     119    "mimetype": "text/x-python",
#     120    "name": "python",
#     121    "nbconvert_exporter": "python",
#     122    "pygments_lexer": "ipython3",
#     123    "version": "3.9.6"
#     124   }
#     125  },
#     126  "nbformat": 4,
#     127  "nbformat_minor": 5
#     128 }
#
# ImportError: cannot import name 'FaceDetectorApp' from 'face_detection' (face_detection.ipynb)
